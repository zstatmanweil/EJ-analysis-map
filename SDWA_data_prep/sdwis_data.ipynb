# %%
import requests
import pandas as pd
import numpy as np
from IPython.display import display
import json
import io

# %% [markdown]
# ## Obtain violation data from Envirofacts RESTful API

# %%
# tmuxta
#url = 'https://iaspub.epa.gov/enviro/efservice/SDW_VIOL_ENFORCEMENT/STATE/NJ/COMPPERBEGINDATE/>/31-DEC-11/COMPPERENDDATE/</01-JAN-17/ROWS/0:30/JSON'
# Identify the whole table
url = 'https://iaspub.epa.gov/enviro/efservice/SDW_VIOL_ENFORCEMENT/STATE/NJ/COMPPERBEGINDATE/>/31-DEC-11/COMPPERENDDATE/</01-JAN-17/CSV'
r = requests.get(url)
if r.status_code == 200:
    vio_df = pd.read_csv(io.StringIO(r.text))
else:
    raise Exception("Request was not valid. Code: {code}".format(code=r.status_code))

# %%
# Explore the data
with pd.option_context('display.max_columns', None):
    display(vio_df.head(5))
# Out:
#   SDW_VIOL_ENFORCEMENT.PWSID SDW_VIOL_ENFORCEMENT.PWSNAME  \
# 0                  NJ0609300     MAUR RIV TWP BD OF ED PO
# 1                  NJ1429302         JNBC ASSOCIATES, LLC
# 2                  NJ1429302         JNBC ASSOCIATES, LLC
# 3                  NJ0408001               CITY OF CAMDEN
# 4                  NJ0612001    BAYSHORE MOBILE HOME PARK
#
#   SDW_VIOL_ENFORCEMENT.STATE SDW_VIOL_ENFORCEMENT.COUNTYSERVED  \
# 0                         NJ                        CUMBERLAND
# 1                         NJ                            MORRIS
# 2                         NJ                            MORRIS
# 3                         NJ                            CAMDEN
# 4                         NJ                        CUMBERLAND
#
#    SDW_VIOL_ENFORCEMENT.VIOID  SDW_VIOL_ENFORCEMENT.CCODE  \
# 0                        1922                        2983
# 1                        8025                        2983
# 2                        8013                        2378
# 3                       50250                        2983
# 4                       22943                        2983
#
#   SDW_VIOL_ENFORCEMENT.CNAME SDW_VIOL_ENFORCEMENT.CTYPE  \
# 0        1,2-Dichloropropane                        VOC
# 1        1,2-Dichloropropane                        VOC
# 2     1,2,4-Trichlorobenzene                        VOC
# 3        1,2-Dichloropropane                        VOC
# 4        1,2-Dichloropropane                        VOC
#
#    SDW_VIOL_ENFORCEMENT.VCODE SDW_VIOL_ENFORCEMENT.VNAME  \
# 0                           3        Monitoring, Regular
# 1                           3        Monitoring, Regular
# 2                           3        Monitoring, Regular
# 3                           3        Monitoring, Regular
# 4                           3        Monitoring, Regular
#
#   SDW_VIOL_ENFORCEMENT.VTYPE SDW_VIOL_ENFORCEMENT.VIOLMEASURE  \
# 0                         MR         Monitoring and Reporting
# 1                         MR         Monitoring and Reporting
# 2                         MR         Monitoring and Reporting
# 3                         MR         Monitoring and Reporting
# 4                         MR         Monitoring and Reporting
#
#   SDW_VIOL_ENFORCEMENT.ENFACTIONTYPE SDW_VIOL_ENFORCEMENT.ENFACTIONNAME  \
# 0                                SFJ               St Formal NOV issued
# 1                                SFJ               St Formal NOV issued
# 2                                SFJ               St Formal NOV issued
# 3                                SFJ               St Formal NOV issued
# 4                                SFM          St Admin Penalty assessed
#
#   SDW_VIOL_ENFORCEMENT.ENFDATE SDW_VIOL_ENFORCEMENT.COMPPERBEGINDATE  \
# 0                    12-JUL-16                             01-APR-16
# 1                    17-JAN-13                             01-OCT-12
# 2                    17-JAN-13                             01-OCT-12
# 3                    19-OCT-16                             01-JUL-16
# 4                    19-JUN-18                             01-JAN-15
#
#   SDW_VIOL_ENFORCEMENT.COMPPERENDDATE  \
# 0                           30-JUN-16
# 1                           31-DEC-12
# 2                           31-DEC-12
# 3                           30-SEP-16
# 4                           31-DEC-15
#
#                    SDW_VIOL_ENFORCEMENT.SOURCES  \
# 0  Discharge from industrial chemical factories
# 1  Discharge from industrial chemical factories
# 2    Discharge from textile finishing factories
# 3  Discharge from industrial chemical factories
# 4  Discharge from industrial chemical factories
#
#                      SDW_VIOL_ENFORCEMENT.DEFINITION  \
# 0  1,2-Dichloropropane is a colorless flammable l...
# 1  1,2-Dichloropropane is a colorless flammable l...
# 2  1,2,4-Trichlorobenzene is an aromatic, colorle...
# 3  1,2-Dichloropropane is a colorless flammable l...
# 4  1,2-Dichloropropane is a colorless flammable l...
#
#   SDW_VIOL_ENFORCEMENT.HEALTH_EFFECTS  Unnamed: 20
# 0            Increased risk of cancer          NaN
# 1            Increased risk of cancer          NaN
# 2           Changes in adrenal glands          NaN
# 3            Increased risk of cancer          NaN
# 4            Increased risk of cancer          NaN

# %%
# Function to clean up headers (will be used below)
def clean_headers(df, to_remove):
    for col in df.columns:
        df = df.rename(index=str, 
                           columns={col: col.replace(to_remove,'')})
    return df

vio_df = clean_headers(vio_df, 'SDW_VIOL_ENFORCEMENT.')
vio_df.head(5)
# Out:
#        PWSID                    PWSNAME STATE COUNTYSERVED  VIOID  CCODE  \
# 0  NJ0609300   MAUR RIV TWP BD OF ED PO    NJ   CUMBERLAND   1922   2983
# 1  NJ1429302       JNBC ASSOCIATES, LLC    NJ       MORRIS   8025   2983
# 2  NJ1429302       JNBC ASSOCIATES, LLC    NJ       MORRIS   8013   2378
# 3  NJ0408001             CITY OF CAMDEN    NJ       CAMDEN  50250   2983
# 4  NJ0612001  BAYSHORE MOBILE HOME PARK    NJ   CUMBERLAND  22943   2983
#
#                     CNAME CTYPE  VCODE                VNAME     ...      \
# 0     1,2-Dichloropropane   VOC      3  Monitoring, Regular     ...
# 1     1,2-Dichloropropane   VOC      3  Monitoring, Regular     ...
# 2  1,2,4-Trichlorobenzene   VOC      3  Monitoring, Regular     ...
# 3     1,2-Dichloropropane   VOC      3  Monitoring, Regular     ...
# 4     1,2-Dichloropropane   VOC      3  Monitoring, Regular     ...
#
#                 VIOLMEASURE ENFACTIONTYPE              ENFACTIONNAME  \
# 0  Monitoring and Reporting           SFJ       St Formal NOV issued
# 1  Monitoring and Reporting           SFJ       St Formal NOV issued
# 2  Monitoring and Reporting           SFJ       St Formal NOV issued
# 3  Monitoring and Reporting           SFJ       St Formal NOV issued
# 4  Monitoring and Reporting           SFM  St Admin Penalty assessed
#
#      ENFDATE COMPPERBEGINDATE COMPPERENDDATE  \
# 0  12-JUL-16        01-APR-16      30-JUN-16
# 1  17-JAN-13        01-OCT-12      31-DEC-12
# 2  17-JAN-13        01-OCT-12      31-DEC-12
# 3  19-OCT-16        01-JUL-16      30-SEP-16
# 4  19-JUN-18        01-JAN-15      31-DEC-15
#
#                                         SOURCES  \
# 0  Discharge from industrial chemical factories
# 1  Discharge from industrial chemical factories
# 2    Discharge from textile finishing factories
# 3  Discharge from industrial chemical factories
# 4  Discharge from industrial chemical factories
#
#                                           DEFINITION  \
# 0  1,2-Dichloropropane is a colorless flammable l...
# 1  1,2-Dichloropropane is a colorless flammable l...
# 2  1,2,4-Trichlorobenzene is an aromatic, colorle...
# 3  1,2-Dichloropropane is a colorless flammable l...
# 4  1,2-Dichloropropane is a colorless flammable l...
#
#               HEALTH_EFFECTS Unnamed: 20
# 0   Increased risk of cancer         NaN
# 1   Increased risk of cancer         NaN
# 2  Changes in adrenal glands         NaN
# 3   Increased risk of cancer         NaN
# 4   Increased risk of cancer         NaN
#
# [5 rows x 21 columns]

# %%
vio_df['health_based'] = np.where(
                        (np.logical_or(vio_df['VTYPE']=='MR',vio_df['VTYPE']=='OTHER')),'N','Y')

# %%
with pd.option_context('display.max_columns', None):
    display(vio_df.head(5))
# Out:
#        PWSID                    PWSNAME STATE COUNTYSERVED  VIOID  CCODE  \
# 0  NJ0609300   MAUR RIV TWP BD OF ED PO    NJ   CUMBERLAND   1922   2983
# 1  NJ1429302       JNBC ASSOCIATES, LLC    NJ       MORRIS   8025   2983
# 2  NJ1429302       JNBC ASSOCIATES, LLC    NJ       MORRIS   8013   2378
# 3  NJ0408001             CITY OF CAMDEN    NJ       CAMDEN  50250   2983
# 4  NJ0612001  BAYSHORE MOBILE HOME PARK    NJ   CUMBERLAND  22943   2983
#
#                     CNAME CTYPE  VCODE                VNAME VTYPE  \
# 0     1,2-Dichloropropane   VOC      3  Monitoring, Regular    MR
# 1     1,2-Dichloropropane   VOC      3  Monitoring, Regular    MR
# 2  1,2,4-Trichlorobenzene   VOC      3  Monitoring, Regular    MR
# 3     1,2-Dichloropropane   VOC      3  Monitoring, Regular    MR
# 4     1,2-Dichloropropane   VOC      3  Monitoring, Regular    MR
#
#                 VIOLMEASURE ENFACTIONTYPE              ENFACTIONNAME  \
# 0  Monitoring and Reporting           SFJ       St Formal NOV issued
# 1  Monitoring and Reporting           SFJ       St Formal NOV issued
# 2  Monitoring and Reporting           SFJ       St Formal NOV issued
# 3  Monitoring and Reporting           SFJ       St Formal NOV issued
# 4  Monitoring and Reporting           SFM  St Admin Penalty assessed
#
#      ENFDATE COMPPERBEGINDATE COMPPERENDDATE  \
# 0  12-JUL-16        01-APR-16      30-JUN-16
# 1  17-JAN-13        01-OCT-12      31-DEC-12
# 2  17-JAN-13        01-OCT-12      31-DEC-12
# 3  19-OCT-16        01-JUL-16      30-SEP-16
# 4  19-JUN-18        01-JAN-15      31-DEC-15
#
#                                         SOURCES  \
# 0  Discharge from industrial chemical factories
# 1  Discharge from industrial chemical factories
# 2    Discharge from textile finishing factories
# 3  Discharge from industrial chemical factories
# 4  Discharge from industrial chemical factories
#
#                                           DEFINITION  \
# 0  1,2-Dichloropropane is a colorless flammable l...
# 1  1,2-Dichloropropane is a colorless flammable l...
# 2  1,2,4-Trichlorobenzene is an aromatic, colorle...
# 3  1,2-Dichloropropane is a colorless flammable l...
# 4  1,2-Dichloropropane is a colorless flammable l...
#
#               HEALTH_EFFECTS  Unnamed: 20 health_based
# 0   Increased risk of cancer          NaN            N
# 1   Increased risk of cancer          NaN            N
# 2  Changes in adrenal glands          NaN            N
# 3   Increased risk of cancer          NaN            N
# 4   Increased risk of cancer          NaN            N

# %%
# Identify all violations for each water system
pivot = pd.pivot_table(vio_df,index=['PWSID','VIOID','health_based'])
pivot = pivot.reset_index().drop(columns=['CCODE','VCODE'])
pivot.head(10)
# Out:
#        PWSID        VIOID health_based
# 0  CT0320044       143511            N
# 1  CT0347031       342114            N
# 2  FL3424829  20120005135            N
# 3  FL6295268  20160000554            N
# 4  FL6295268  20160000555            N
# 5  FL6295268  20160000574            N
# 6  FL6295268  20160000575            N
# 7  FL6295268  20160000608            N
# 8  FL6295268  20160000609            N
# 9  FL6295268  20160000633            N

# %%
# Identify all health-based violations for each water system
health_vio_df = vio_df[vio_df.health_based=='Y']
health_pivot = pd.pivot_table(health_vio_df,index=['PWSID','VIOID','health_based'])
health_pivot = health_pivot.reset_index().drop(columns=['CCODE','VCODE'])
health_pivot.head(10)
# Out:
#        PWSID  VIOID health_based
# 0  NJ0102301   2111            Y
# 1  NJ0104322    811            Y
# 2  NJ0105301    511            Y
# 3  NJ0105304  11111            Y
# 4  NJ0105304  11112            Y
# 5  NJ0105323   2109            Y
# 6  NJ0105333   2214            Y
# 7  NJ0105333   2215            Y
# 8  NJ0105333   2216            Y
# 9  NJ0105333   2217            Y

# %%
# Summarize total violations per water system
vio_by_pws = pd.pivot_table(pivot,index=['PWSID'],aggfunc='count')
vio_by_pws = vio_by_pws.reset_index().drop(columns='health_based')
vio_by_pws = vio_by_pws.rename(columns={'VIOID': 'all_violations'})
vio_by_pws.head(5)
# Out:
#        PWSID  all_violations
# 0  CT0320044               1
# 1  CT0347031               1
# 2  FL3424829               1
# 3  FL6295268              12
# 4  GA2310025               1

# %%
# Summarize health-based violations per water system
health_vio_by_pws = pd.pivot_table(health_pivot,index=['PWSID'],aggfunc='count')
health_vio_by_pws = health_vio_by_pws.reset_index().drop(columns='health_based')
health_vio_by_pws = health_vio_by_pws.rename(columns={'VIOID': 'health_violations'})
health_vio_by_pws.head(5)
# Out:
#        PWSID  health_violations
# 0  NJ0102301                  1
# 1  NJ0104322                  1
# 2  NJ0105301                  1
# 3  NJ0105304                  2
# 4  NJ0105323                  1

# %%
# Merge tables into one datasets
sdwa_vios = pd.merge(vio_by_pws, health_vio_by_pws, how='outer', on='PWSID')

# %%
# Convert null values to 0
sdwa_vios.fillna(0, inplace=True)

# %%
sdwa_vios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1423 entries, 0 to 1422
# Data columns (total 3 columns):
# PWSID                1423 non-null object
# all_violations       1423 non-null int64
# health_violations    1423 non-null float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 44.5+ KB

# %%
# Convert health_violations field type to int64 to match all_violations field type
sdwa_vios['health_violations'] = sdwa_vios['health_violations'].astype('int64')

# %%
# Confirm dataset looks good
sdwa_vios.head(10)
# Out:
#        PWSID  all_violations  health_violations
# 0  CT0320044               1                  0
# 1  CT0347031               1                  0
# 2  FL3424829               1                  0
# 3  FL6295268              12                  0
# 4  GA2310025               1                  0
# 5  LA1019085               1                  0
# 6  ME0000802               2                  0
# 7  ME0094466               2                  0
# 8  NJ0102001               6                  0
# 9  NJ0102301               2                  1

# %%
sdwa_vios.to_csv('..\Data\Created\SDWIS\sdwa_vios.csv', index=False)

# %% [markdown]
# ## Obtain water system characteristic data from Envirofacts RESTful API

# %%
# Identify the the table of interest
url = 'https://iaspub.epa.gov/enviro/efservice/WATER_SYSTEM/STATE_CODE/NJ/CSV'
r = requests.get(url)
if r.status_code == 200:
    pws_df = pd.read_csv(io.StringIO(r.text))
else:
    raise Exception("Request was not valid. Code: {code}".format(code=r.status_code))

# %%
pws_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10001 entries, 0 to 10000
# Data columns (total 48 columns):
# WATER_SYSTEM.PWSID                             10001 non-null object
# WATER_SYSTEM.PWS_NAME                          9983 non-null object
# WATER_SYSTEM.NPM_CANDIDATE                     10001 non-null object
# WATER_SYSTEM.PRIMACY_AGENCY_CODE               10001 non-null object
# WATER_SYSTEM.EPA_REGION                        10001 non-null int64
# WATER_SYSTEM.SEASON_BEGIN_DATE                 9436 non-null object
# WATER_SYSTEM.SEASON_END_DATE                   9436 non-null object
# WATER_SYSTEM.PWS_ACTIVITY_CODE                 10001 non-null object
# WATER_SYSTEM.PWS_DEACTIVATION_DATE             7032 non-null object
# WATER_SYSTEM.PWS_TYPE_CODE                     10001 non-null object
# WATER_SYSTEM.DBPR_SCHEDULE_CAT_CODE            571 non-null float64
# WATER_SYSTEM.CDS_ID                            569 non-null float64
# WATER_SYSTEM.GW_SW_CODE                        10000 non-null object
# WATER_SYSTEM.LT2_SCHEDULE_CAT_CODE             33 non-null float64
# WATER_SYSTEM.OWNER_TYPE_CODE                   7918 non-null object
# WATER_SYSTEM.POPULATION_SERVED_COUNT           10001 non-null int64
# WATER_SYSTEM.POP_CAT_2_CODE                    10001 non-null int64
# WATER_SYSTEM.POP_CAT_3_CODE                    10001 non-null int64
# WATER_SYSTEM.POP_CAT_4_CODE                    10001 non-null int64
# WATER_SYSTEM.POP_CAT_5_CODE                    10001 non-null int64
# WATER_SYSTEM.POP_CAT_11_CODE                   10001 non-null int64
# WATER_SYSTEM.PRIMACY_TYPE                      10001 non-null object
# WATER_SYSTEM.PRIMARY_SOURCE_CODE               10000 non-null object
# WATER_SYSTEM.IS_GRANT_ELIGIBLE_IND             10001 non-null object
# WATER_SYSTEM.IS_WHOLESALER_IND                 10001 non-null object
# WATER_SYSTEM.IS_SCHOOL_OR_DAYCARE_IND          10001 non-null object
# WATER_SYSTEM.SERVICE_CONNECTIONS_COUNT         10001 non-null int64
# WATER_SYSTEM.SUBMISSION_STATUS_CODE            10001 non-null object
# WATER_SYSTEM.ORG_NAME                          3764 non-null object
# WATER_SYSTEM.ADMIN_NAME                        7303 non-null object
# WATER_SYSTEM.EMAIL_ADDR                        98 non-null object
# WATER_SYSTEM.PHONE_NUMBER                      8433 non-null object
# WATER_SYSTEM.PHONE_EXT_NUMBER                  313 non-null float64
# WATER_SYSTEM.FAX_NUMBER                        1638 non-null object
# WATER_SYSTEM.ALT_PHONE_NUMBER                  2 non-null float64
# WATER_SYSTEM.ADDRESS_LINE1                     6589 non-null object
# WATER_SYSTEM.ADDRESS_LINE2                     6519 non-null object
# WATER_SYSTEM.CITY_NAME                         9996 non-null object
# WATER_SYSTEM.ZIP_CODE                          8870 non-null object
# WATER_SYSTEM.COUNTRY_CODE                      10001 non-null object
# WATER_SYSTEM.STATE_CODE                        10001 non-null object
# WATER_SYSTEM.SOURCE_WATER_PROTECTION_CODE      3646 non-null object
# WATER_SYSTEM.SOURCE_PROTECTION_BEGIN_DATE      13 non-null object
# WATER_SYSTEM.OUTSTANDING_PERFORMER             4 non-null object
# WATER_SYSTEM.OUTSTANDING_PERFORM_BEGIN_DATE    0 non-null float64
# WATER_SYSTEM.CITIES_SERVED                     10001 non-null object
# WATER_SYSTEM.COUNTIES_SERVED                   10001 non-null object
# Unnamed: 47                                    0 non-null float64
# dtypes: float64(7), int64(8), object(33)
# memory usage: 3.7+ MB

# %%
# Filter and explore the data
pws_df = clean_headers(pws_df, 'WATER_SYSTEM.')
filters = (pws_df.STATE_CODE == 'NJ') & \
            (pws_df.PWS_ACTIVITY_CODE == 'A') & \
            (pws_df.PWS_TYPE_CODE == 'CWS')
pws_df = pws_df[filters]
pws_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 494 entries, 0 to 9201
# Data columns (total 48 columns):
# PWSID                             494 non-null object
# PWS_NAME                          494 non-null object
# NPM_CANDIDATE                     494 non-null object
# PRIMACY_AGENCY_CODE               494 non-null object
# EPA_REGION                        494 non-null int64
# SEASON_BEGIN_DATE                 0 non-null object
# SEASON_END_DATE                   0 non-null object
# PWS_ACTIVITY_CODE                 494 non-null object
# PWS_DEACTIVATION_DATE             0 non-null object
# PWS_TYPE_CODE                     494 non-null object
# DBPR_SCHEDULE_CAT_CODE            411 non-null float64
# CDS_ID                            408 non-null float64
# GW_SW_CODE                        494 non-null object
# LT2_SCHEDULE_CAT_CODE             29 non-null float64
# OWNER_TYPE_CODE                   494 non-null object
# POPULATION_SERVED_COUNT           494 non-null int64
# POP_CAT_2_CODE                    494 non-null int64
# POP_CAT_3_CODE                    494 non-null int64
# POP_CAT_4_CODE                    494 non-null int64
# POP_CAT_5_CODE                    494 non-null int64
# POP_CAT_11_CODE                   494 non-null int64
# PRIMACY_TYPE                      494 non-null object
# PRIMARY_SOURCE_CODE               494 non-null object
# IS_GRANT_ELIGIBLE_IND             494 non-null object
# IS_WHOLESALER_IND                 494 non-null object
# IS_SCHOOL_OR_DAYCARE_IND          494 non-null object
# SERVICE_CONNECTIONS_COUNT         494 non-null int64
# SUBMISSION_STATUS_CODE            494 non-null object
# ORG_NAME                          494 non-null object
# ADMIN_NAME                        494 non-null object
# EMAIL_ADDR                        15 non-null object
# PHONE_NUMBER                      464 non-null object
# PHONE_EXT_NUMBER                  71 non-null float64
# FAX_NUMBER                        156 non-null object
# ALT_PHONE_NUMBER                  0 non-null float64
# ADDRESS_LINE1                     493 non-null object
# ADDRESS_LINE2                     74 non-null object
# CITY_NAME                         494 non-null object
# ZIP_CODE                          494 non-null object
# COUNTRY_CODE                      494 non-null object
# STATE_CODE                        494 non-null object
# SOURCE_WATER_PROTECTION_CODE      477 non-null object
# SOURCE_PROTECTION_BEGIN_DATE      9 non-null object
# OUTSTANDING_PERFORMER             1 non-null object
# OUTSTANDING_PERFORM_BEGIN_DATE    0 non-null float64
# CITIES_SERVED                     494 non-null object
# COUNTIES_SERVED                   494 non-null object
# Unnamed: 47                       0 non-null float64
# dtypes: float64(7), int64(8), object(33)
# memory usage: 189.1+ KB

# %%
# Only utilize necessary columns
pws_clean = pws_df.filter(['PWSID',
                           'PRIMARY_SOURCE_CODE',
                           'OWNER_TYPE_CODE', 
                           'SERVICE_CONNECTIONS_COUNT',
                           'COUNTIES_SERVED'], axis=1)

# %%
pws_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 494 entries, 0 to 9201
# Data columns (total 5 columns):
# PWSID                        494 non-null object
# PRIMARY_SOURCE_CODE          494 non-null object
# OWNER_TYPE_CODE              494 non-null object
# SERVICE_CONNECTIONS_COUNT    494 non-null int64
# COUNTIES_SERVED              494 non-null object
# dtypes: int64(1), object(4)
# memory usage: 23.2+ KB

# %%
# Merge with the rest of the PWS data
sdwa_vios_merged = pd.merge(pws_clean, sdwa_vios, how='left', on='PWSID', validate="one_to_one")
sdwa_vios_merged.head()
# Out:
#        PWSID PRIMARY_SOURCE_CODE OWNER_TYPE_CODE  SERVICE_CONNECTIONS_COUNT  \
# 0  NJ1432001                  GW               L                         10
# 1  NJ1435002                  GW               L                       4350
# 2  NJ1503001                  GW               L                       2253
# 3  NJ1522001                  GW               L                        933
# 4  NJ1005001                  GW               L                       4600
#
#   COUNTIES_SERVED  all_violations  health_violations
# 0          Morris            30.0                0.0
# 1          Morris             5.0                0.0
# 2           Ocean             1.0                1.0
# 3           Ocean             1.0                0.0
# 4       Hunterdon             4.0                0.0

# %%
# Convert violation fields to integer type
sdwa_vios_merged['health_violations'] = sdwa_vios['health_violations'].astype('int64')
sdwa_vios_merged['all_violations'] = sdwa_vios['all_violations'].astype('int64')

# %%
# Write out full names for codes
# Identyify a full list of codes
print(set(sdwa_vios_merged['PRIMARY_SOURCE_CODE']))
print(set(sdwa_vios_merged['OWNER_TYPE_CODE']))
# Out:
# set(['GW', 'SWP', 'GU', 'SW', 'GWP'])
# set(['P', 'S', 'M', 'L', 'F'])

# %%
psc = {'GW': 'Ground water', 
       'SW': 'Surface water', 
       'SWP': 'Surface water purchased', 
       'GWP': 'Groundwater purchased',
       'GU': 'Ground water under influence of surface water source'}
otc = {'M': 'Mixed', 
       'S': 'State Government', 
       'F': 'Federal Government', 
       'P': 'Private', 
       'L': 'Local Government'}

def psc_to_description(code):
    return psc[code]

def otc_to_description(code):
    return otc[code]

# %%
sdwa_vios_merged['primary_source'] = sdwa_vios_merged['PRIMARY_SOURCE_CODE'].apply(psc_to_description)
sdwa_vios_merged['owner_type'] = sdwa_vios_merged['OWNER_TYPE_CODE'].apply(otc_to_description)

# %%
sdwa_vios_merged.head()
# Out:
#        PWSID PRIMARY_SOURCE_CODE OWNER_TYPE_CODE  SERVICE_CONNECTIONS_COUNT  \
# 0  NJ1432001                  GW               L                         10
# 1  NJ1435002                  GW               L                       4350
# 2  NJ1503001                  GW               L                       2253
# 3  NJ1522001                  GW               L                        933
# 4  NJ1005001                  GW               L                       4600
#
#   COUNTIES_SERVED  all_violations  health_violations primary_source  \
# 0          Morris               1                  0   Ground water
# 1          Morris               1                  0   Ground water
# 2           Ocean               1                  0   Ground water
# 3           Ocean              12                  0   Ground water
# 4       Hunterdon               1                  0   Ground water
#
#          owner_type
# 0  Local Government
# 1  Local Government
# 2  Local Government
# 3  Local Government
# 4  Local Government

# %%
# Replace all null values in the violation fields with with 0 since if there 
# isn't violation data  for a water system that means the water system did not 
# recieve a violation.
sdwa_vios_merged.fillna(0, inplace=True)

# %%
sdwa_vios_merged.to_csv('..\Data\Created\SDWIS\sdwa_vios_complete.csv', index=False)
